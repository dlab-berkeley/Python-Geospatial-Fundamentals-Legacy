# %% [markdown]
# # 7. Spatial Relations

# %%
berkeley_parcels_new = berkeley_parcels_gdf[berkeley_parcels_gdf.within(berkeley_outline['geometry'].squeeze())]

# %%
# Set up the plot with a bigger size
fig, ax = plt.subplots(figsize = (15,15)) 


# Add the census tract polygons as our background layer
berkeley_outline.plot(color='lightgrey',
                    edgecolor='white',
                    ax=ax)

# Add the points to the map
berkeley_parcels_new.sort_values(by='totvalue2').plot(ax=ax,
                                                      legend=True, 
                                                      cmap="winter",
                                                      alpha=0.75,
                                                      markersize=30,
                                                      vmin=1)  # Set a value for the low vis value

plt.show()

# %%
#berkeley_parcels_new = berkeley_parcels_gdf[berkeley_parcels_gdf.within(berkeley_outline['geometry'].squeeze())]

# Set up the plot with a bigger size
fig, ax = plt.subplots(figsize = (15,15)) 


# Add the census tract polygons as our background layer
berkeley_outline.plot(color='lightgrey',
                    edgecolor='white',
                    ax=ax)

# Add the points to the map
berkeley_parcels_new.sort_values(by='totvalue2').plot(ax=ax,
                                                      legend=True, 
                                                      cmap="winter",
                                                      alpha=0.75,
                                                      markersize=30,
                                                      vmin=1)  # Set a value for the low vis value

plt.show()
