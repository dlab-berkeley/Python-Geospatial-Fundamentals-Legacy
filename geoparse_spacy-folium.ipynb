# %% [markdown]
# ## Extracting and Mapping Place Names
#
#
# ### Introduction
#
# This notebook demonstrates the power of and problems with automated geoparsing. **Geoparsing** is a term used for two related tasks:
# 1. **[NER: named entity recognition](https://en.wikipedia.org/wiki/Named-entity_recognition)**, the automatic extraction of named terms from a text documents, with the focus on place names and locations.
# 2. **[Geocoding](https://en.wikipedia.org/wiki/Geocoding)**, the process of determining the geographic coordinates for place names, codes and street addresses.
#
# Why geoparse? One reason might be to determine all locations that are mentioned in a text. Another might be to determine only the most important locations, which might be indicated by how often they are mentioned or where they are mentioned, e.g., in a title or chapter heading. The output of geoparsing can be used to answer all types of questions, like 'What was the geographic evolution of the use of the term *dude*?
#
# NER and geocoding are complex computational tasks that are beyond the scope of this notebook. Instead, this notebook aims to get you thinking about the complexity and richness of place names and the value of coordinate representations of places, both of which make geoparasing so important.
#
#
# #### In this notebook we:
# 1. Fetch the text of the book ['Around the World in 80 Days' by Jules Verne](http://www.gutenberg.org/cache/epub/103/pg103.txt) from the [Project Gutenberg](http://www.gutenberg.org) online library.
# 2. Extract place name references from that text using the Python natural language processing library [SpaCy](https://spacy.io/)
# 3. Geocode the place names with [Geopy](https://geopy.readthedocs.io/en/1.10.0/) package and the [Nominatim](http://nominatim.org/) open source geocoder from [OpenStreetMap](https://en.wikipedia.org/wiki/OpenStreetMap).
# 4. Map the named place locations with the maps module of the [datascience](https://github.com/data-8/datascience) package.
#
# #### Learning goals:
# - Think about the difference in place name vs. coordinate representations of locations.
# - Experience the power and challenges of automated place name extraction.
# - Consider some of the things you can do with the place names once they are geocoded.
#
# <hr/>

# %% [markdown]
# # [SpaCy](https://spacy.io/): Industrial-Strength NLP
#
# The tradtional NLP library has always been [NLTK](http://www.nltk.org/). While `NLTK` is still very useful for linguistics analysis and exporation, `SpaCy` has become a nice option for easy and fast implementation of the NLP pipeline. What's the NLP pipeline? It's a number of common steps computational linguists perform to help them (and the computer) better understand textual data. Digital Humanists are often fond of the pipeline because it gives us more things to count! (Source: Chris Hench, ....)
#
# SpaCy is full-featured and super fast. But in this exercise we are just getting a little taste.

# %% [markdown]
# ### Step 0. Install SpaCy if you don't have it
#
# Uncomment and run the following cell to install SpaCy and its core English language processing tools.

# %%
# !pip install spacy
# !python -m spacy download en
# Out:
# Requirement already satisfied: spacy in /Applications/anaconda3/lib/python3.6/site-packages (2.0.5)
# Requirement already satisfied: murmurhash<0.29,>=0.28 in /Applications/anaconda3/lib/python3.6/site-packages (from spacy) (0.28.0)
# Requirement already satisfied: pathlib in /Applications/anaconda3/lib/python3.6/site-packages (from spacy) (1.0.1)
# Requirement already satisfied: regex==2017.4.5 in /Applications/anaconda3/lib/python3.6/site-packages (from spacy) (2017.4.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Applications/anaconda3/lib/python3.6/site-packages (from spacy) (2.18.4)
# Requirement already satisfied: six in /Applications/anaconda3/lib/python3.6/site-packages (from spacy) (1.11.0)
# Requirement already satisfied: dill<0.3,>=0.2 in /Applications/anaconda3/lib/python3.6/site-packages (from spacy) (0.2.7.1)
# Requirement already satisfied: ftfy<5.0.0,>=4.4.2 in /Applications/anaconda3/lib/python3.6/site-packages (from spacy) (4.4.3)
# Requirement already satisfied: ujson>=1.35 in /Applications/anaconda3/lib/python3.6/site-packages (from spacy) (1.35)
# Requirement already satisfied: numpy>=1.7 in /Applications/anaconda3/lib/python3.6/site-packages (from spacy) (1.13.3)
# Requirement already satisfied: cymem<1.32,>=1.30 in /Applications/anaconda3/lib/python3.6/site-packages (from spacy) (1.31.2)
# Requirement already satisfied: thinc<6.11.0,>=6.10.1 in /Applications/anaconda3/lib/python3.6/site-packages (from spacy) (6.10.2)
# Requirement already satisfied: msgpack-numpy==0.4.1 in /Applications/anaconda3/lib/python3.6/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: msgpack-python in /Applications/anaconda3/lib/python3.6/site-packages (from spacy) (0.4.8)
# Requirement already satisfied: preshed<2.0.0,>=1.0.0 in /Applications/anaconda3/lib/python3.6/site-packages (from spacy) (1.0.0)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /Applications/anaconda3/lib/python3.6/site-packages (from spacy) (0.9.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Applications/anaconda3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /Applications/anaconda3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /Applications/anaconda3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /Applications/anaconda3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2018.4.16)
# Requirement already satisfied: wcwidth in /Applications/anaconda3/lib/python3.6/site-packages (from ftfy<5.0.0,>=4.4.2->spacy) (0.1.7)
# Requirement already satisfied: html5lib in /Applications/anaconda3/lib/python3.6/site-packages (from ftfy<5.0.0,>=4.4.2->spacy) (0.999999999)
# Requirement already satisfied: cytoolz<0.9,>=0.8 in /Applications/anaconda3/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.1->spacy) (0.8.2)
# Requirement already satisfied: wrapt in /Applications/anaconda3/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.1->spacy) (1.10.11)
# Requirement already satisfied: termcolor in /Applications/anaconda3/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.1->spacy) (1.1.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /Applications/anaconda3/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.1->spacy) (4.19.5)
# Requirement already satisfied: webencodings in /Applications/anaconda3/lib/python3.6/site-packages (from html5lib->ftfy<5.0.0,>=4.4.2->spacy) (0.5.1)
# Requirement already satisfied: setuptools>=18.5 in /Applications/anaconda3/lib/python3.6/site-packages (from html5lib->ftfy<5.0.0,>=4.4.2->spacy) (38.5.2)
# Requirement already satisfied: toolz>=0.8.0 in /Applications/anaconda3/lib/python3.6/site-packages (from cytoolz<0.9,>=0.8->thinc<6.11.0,>=6.10.1->spacy) (0.8.2)
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz (37.4MB)
#     100% |████████████████████████████████| 37.4MB 1.5MB/s ta 0:00:011
# Requirement already satisfied (use --upgrade to upgrade): en-core-web-sm==2.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz in /Applications/anaconda3/lib/python3.6/site-packages
# Requirement already satisfied: spacy>=2.0.0a18 in /Applications/anaconda3/lib/python3.6/site-packages (from en-core-web-sm==2.0.0) (2.0.5)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /Applications/anaconda3/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (0.9.6)
# Requirement already satisfied: cymem<1.32,>=1.30 in /Applications/anaconda3/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (1.31.2)
# Requirement already satisfied: thinc<6.11.0,>=6.10.1 in /Applications/anaconda3/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (6.10.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Applications/anaconda3/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (2.18.4)
# Requirement already satisfied: six in /Applications/anaconda3/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (1.11.0)
# Requirement already satisfied: pathlib in /Applications/anaconda3/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (1.0.1)
# Requirement already satisfied: preshed<2.0.0,>=1.0.0 in /Applications/anaconda3/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (1.0.0)
# Requirement already satisfied: numpy>=1.7 in /Applications/anaconda3/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (1.13.3)
# Requirement already satisfied: msgpack-numpy==0.4.1 in /Applications/anaconda3/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (0.4.1)
# Requirement already satisfied: msgpack-python in /Applications/anaconda3/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (0.4.8)
# Requirement already satisfied: ftfy<5.0.0,>=4.4.2 in /Applications/anaconda3/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (4.4.3)
# Requirement already satisfied: ujson>=1.35 in /Applications/anaconda3/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (1.35)
# Requirement already satisfied: regex==2017.4.5 in /Applications/anaconda3/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (2017.4.5)
# Requirement already satisfied: dill<0.3,>=0.2 in /Applications/anaconda3/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (0.2.7.1)
# Requirement already satisfied: murmurhash<0.29,>=0.28 in /Applications/anaconda3/lib/python3.6/site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0) (0.28.0)
# Requirement already satisfied: termcolor in /Applications/anaconda3/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.1->spacy>=2.0.0a18->en-core-web-sm==2.0.0) (1.1.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /Applications/anaconda3/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.1->spacy>=2.0.0a18->en-core-web-sm==2.0.0) (4.19.5)
# Requirement already satisfied: wrapt in /Applications/anaconda3/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.1->spacy>=2.0.0a18->en-core-web-sm==2.0.0) (1.10.11)
# Requirement already satisfied: cytoolz<0.9,>=0.8 in /Applications/anaconda3/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.1->spacy>=2.0.0a18->en-core-web-sm==2.0.0) (0.8.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Applications/anaconda3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.0a18->en-core-web-sm==2.0.0) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /Applications/anaconda3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.0a18->en-core-web-sm==2.0.0) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /Applications/anaconda3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.0a18->en-core-web-sm==2.0.0) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /Applications/anaconda3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.0a18->en-core-web-sm==2.0.0) (2018.4.16)
# Requirement already satisfied: wcwidth in /Applications/anaconda3/lib/python3.6/site-packages (from ftfy<5.0.0,>=4.4.2->spacy>=2.0.0a18->en-core-web-sm==2.0.0) (0.1.7)
# Requirement already satisfied: html5lib in /Applications/anaconda3/lib/python3.6/site-packages (from ftfy<5.0.0,>=4.4.2->spacy>=2.0.0a18->en-core-web-sm==2.0.0) (0.999999999)
# Requirement already satisfied: toolz>=0.8.0 in /Applications/anaconda3/lib/python3.6/site-packages (from cytoolz<0.9,>=0.8->thinc<6.11.0,>=6.10.1->spacy>=2.0.0a18->en-core-web-sm==2.0.0) (0.8.2)
# Requirement already satisfied: webencodings in /Applications/anaconda3/lib/python3.6/site-packages (from html5lib->ftfy<5.0.0,>=4.4.2->spacy>=2.0.0a18->en-core-web-sm==2.0.0) (0.5.1)
# Requirement already satisfied: setuptools>=18.5 in /Applications/anaconda3/lib/python3.6/site-packages (from html5lib->ftfy<5.0.0,>=4.4.2->spacy>=2.0.0a18->en-core-web-sm==2.0.0) (38.5.2)
#
#     Linking successful
#     /Applications/anaconda3/lib/python3.6/site-packages/en_core_web_sm -->
#     /Applications/anaconda3/lib/python3.6/site-packages/spacy/data/en
#
#     You can now load the model via spacy.load('en')

# %% [markdown]
# ### Step 1. Load the python libraries we will use.

# %%
from datascience import *
import requests
from collections import Counter
import spacy
import numpy as np
import folium
#nlp = spacy.load('en')
nlp = spacy.load('en', parser=False)  # run this instead if you don't have > 1GB RAM

# %% [markdown]
# Let's test SpaCy to make sure it's working and see its output. the `nlp` function will parse the input text and create a model of the document that can then be used for text processing. Below is an example from the SpaCy web site.

# %%
# Process whole documents
text = (u"When Sebastian Thrun started working on self-driving cars at "
        u"Google in 2007, few people outside of the company took him "
        u"seriously. “I can tell you very senior CEOs of major American "
        u"car companies would shake my hand and turn away because I wasn’t "
        u"worth talking to,” said Thrun, now the co-founder and CEO of "
        u"online higher education startup Udacity, in an interview with "
        u"Recode earlier this week.")
doc_model = nlp(text)

# %% [markdown]
# SpaCy makes it easy to extract named entities and their [types](https://spacy.io/usage/linguistic-features#entity-types).

# %%
# Find named entities, phrases and concepts
for entity in doc_model.ents:
    print(entity.text, entity.label_)
# Out:
# Sebastian Thrun PERSON
# Google ORG
# 2007 DATE
# American NORP
# Thrun PERSON
# Recode ORG
# earlier this week DATE

# %% [markdown]
# The `Counter` module of the `collections` package will help us keep count of the named entities we parse.  An example of this is shown below for the text we just processed.

# %%
my_places = []
for ent in doc_model.ents:
    if ent.label_ == "GPE":
        my_places.append(ent.text.strip())

my_places = Counter(my_places)
my_places
# Out:
# Counter()

# %% [markdown]
# ### Step 2. Fetch the text we want to geoparse
#
# In this exercise we will geoparse the book ['Around the World in 80 Days' by Jules Verne](http://www.gutenberg.org/files/103/103.txt). You can check it out in your browser via the URL http://www.gutenberg.org/files/103/103.txt.
#
# We are fetching the book from the [Project Gutenberg](http://www.gutenberg.org) website, the first online provider of free electronic books, or eBooks, currently hosting over 57,000 books.

# %%
## Downloaded from Project Gutenberg
text_url = "http://www.gutenberg.org/files/103/103.txt"
## Alt url if that doesn't work
#text_url = 'https://raw.githubusercontent.com/data-8/geospatial-connector/gh-pages/data/around_world_80days.txt' 

the_text = requests.get(text_url).text
the_text = the_text[4191:].replace('\r\n', ' ')  # fix formatting and skip title header

# %% [markdown]
# ### Step 3. Process the text with SpaCy

# %% [markdown]
# Parse the text with `SpaCy.nlp`.

# %%
parsed_text = nlp(the_text)

# %% [markdown]
# Extract and Count the named places - those with the entity type `GPE`.

# %%
places = []

for ent in parsed_text.ents:
    if ent.label_ == "GPE":
        places.append(ent.text.strip())

places = Counter(places)
places
# Out:
# Counter({'': 22,
#          '1.A.': 1,
#          'Aden': 8,
#          'Alabama': 2,
#          'Allahabad': 5,
#          'America': 14,
#          'Amphion': 1,
#          'Anam': 1,
#          'Aouda': 134,
#          'Arkansas': 1,
#          'Athens': 1,
#          'Aurungabad': 1,
#          'Bab-el-Mandeb': 1,
#          'Bah': 2,
#          'Baring': 2,
#          'Behar': 2,
#          'Benares': 5,
#          'Bengal': 2,
#          'Biblical': 1,
#          'Birmingham': 1,
#          'Bombay': 58,
#          'Boulevard': 1,
#          'Brazil': 1,
#          'Brindisi': 8,
#          'Burdwan': 1,
#          'Burglars': 1,
#          'Buxar': 1,
#          'Calais': 1,
#          'California': 2,
#          'Camerfield': 4,
#          'Captain--': 1,
#          'Chandernagor': 2,
#          'Cheshire': 1,
#          'Chicago': 7,
#          'Chili': 1,
#          'China': 13,
#          'Chinamen': 1,
#          'Cisco': 1,
#          'Colfax': 1,
#          'Colorado': 3,
#          'Columbus': 1,
#          'Consul': 2,
#          'Creek': 1,
#          'Denver': 1,
#          'Des Moines': 1,
#          'Dover': 3,
#          'Dublin': 3,
#          'Dutchmen': 1,
#          'Edinburgh': 1,
#          'Egypt': 2,
#          'Elephanta': 1,
#          'England': 20,
#          'Englishmen': 4,
#          'Evening': 1,
#          'Fallentin': 2,
#          'Flanagan': 2,
#          'Fogg': 17,
#          'Footsteps': 1,
#          'Formosa': 1,
#          'Fort Saunders': 1,
#          'France': 3,
#          'Fremont': 1,
#          'Germany': 1,
#          'Ghazipur': 1,
#          'Gray': 1,
#          'Great Island': 1,
#          'Green Creek': 1,
#          'Hamburg': 1,
#          'Havre': 1,
#          'Himalaya': 2,
#          'Hindoos': 1,
#          'Holland': 2,
#          'Hong': 1,
#          'Hong Kong': 60,
#          'Honourable': 1,
#          'Hugly': 1,
#          'Illinois': 4,
#          'Independence': 1,
#          'India': 35,
#          'Indiana': 1,
#          'Indus': 1,
#          'Iowa': 1,
#          'Iowa City': 1,
#          'Israel': 1,
#          'Japan': 12,
#          'Jersey City': 1,
#          'Jordan': 3,
#          'Julesburg': 1,
#          'Jumna': 1,
#          'Kansas': 1,
#          'Kholby': 3,
#          'Kiouni': 6,
#          'Kirkland': 1,
#          'Leotard': 1,
#          'Liverpool': 27,
#          'London': 64,
#          'Londoner': 1,
#          'Macao': 3,
#          'Madras': 3,
#          'Malabar': 1,
#          'Malacca': 1,
#          'Manchester': 1,
#          'Mexico': 1,
#          'Mikado': 1,
#          'Mississippi': 3,
#          'Missouri': 4,
#          'Mongolia': 20,
#          'Monsieur': 1,
#          'Murshedabad': 1,
#          'Myself': 1,
#          'Nagasaki': 4,
#          'Nebraska': 4,
#          'Nevada': 1,
#          'New Jersey': 1,
#          'New York': 28,
#          'North 1500 West': 1,
#          'North Platte': 1,
#          'Norway': 1,
#          'Oakland': 1,
#          'Ogden': 1,
#          'Ohio': 3,
#          'Omaha': 24,
#          'Oregon': 1,
#          'Paris': 11,
#          'Parsee': 2,
#          'Parsees': 2,
#          'Passepartout': 3,
#          'Pennsylvania': 1,
#          'Peru': 1,
#          'Pillaji': 9,
#          'Pittsburgh': 1,
#          'Plum Creek': 1,
#          'Queenstown': 1,
#          'Rangoon': 5,
#          'Reading': 1,
#          'Reno': 1,
#          'Royalty': 2,
#          'Sacramento': 7,
#          'Salcette': 2,
#          'Salt Lake City': 4,
#          'San Francisco': 29,
#          'Sedgwick': 1,
#          'Shanghai': 17,
#          'Singapore': 12,
#          'Sioux': 12,
#          'Sullivan': 1,
#          'Surat': 1,
#          'Sweden': 1,
#          'Sydenham': 1,
#          'THE UNITED STATES': 1,
#          'Tankadere': 18,
#          'The Salt Lake': 1,
#          'The United States': 1,
#          'U.S.': 3,
#          'Utah': 6,
#          'Vermont': 2,
#          'Victoria': 2,
#          'Vicvarcarma': 1,
#          'Westminster': 1,
#          'Wyoming': 1,
#          'XV': 1,
#          'Yokohama': 39,
#          'Zoroaster': 1,
#          'a United States': 1,
#          'the Andaman Islands': 1,
#          'the Celestial Empire': 2,
#          'the City of God': 1,
#          'the City of the Saints': 1,
#          'the Empire of the Sun for the States of the Union': 1,
#          'the Great Salt Lake': 2,
#          'the Japanese Empire': 1,
#          'the State of California': 1,
#          'the State of Iowa': 1,
#          'the United Kingdom': 1,
#          'the United States': 14})

# %% [markdown]
# Take a look at the output. What do you think? Was the processing fast? Did it extract named places?  Can you spot any errors?

# %% [markdown]
# You can spend a lot of time cleaning up errors in NER output. It's best to think of ways to automate that.  One simple first cut is to just keep the places with more than a minimal number of mentions. A good way to get a sense of where your cut off point display the places in descending order by count. We can save the information in a table.

# %%
places_table = Table(['name','count']).with_rows(places.most_common())

# %%
# How many places
places_table.num_rows
# Out:
# 175

# %%
# Take a look at the table
places_table.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>name</th> <th>count</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Aouda                                            </td> <td>134  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>London                                           </td> <td>64   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Hong Kong                                        </td> <td>60   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Bombay                                           </td> <td>58   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Yokohama                                         </td> <td>39   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>India                                            </td> <td>35   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>San Francisco                                    </td> <td>29   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>New York                                         </td> <td>28   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Liverpool                                        </td> <td>27   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Omaha                                            </td> <td>24   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>                                                 </td> <td>22   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>England                                          </td> <td>20   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Mongolia                                         </td> <td>20   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Tankadere                                        </td> <td>18   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Fogg                                             </td> <td>17   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Shanghai                                         </td> <td>17   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>America                                          </td> <td>14   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>the United States                                </td> <td>14   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>China                                            </td> <td>13   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Singapore                                        </td> <td>12   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Japan                                            </td> <td>12   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Sioux                                            </td> <td>12   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Paris                                            </td> <td>11   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Pillaji                                          </td> <td>9    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Brindisi                                         </td> <td>8    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Aden                                             </td> <td>8    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Sacramento                                       </td> <td>7    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Chicago                                          </td> <td>7    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Kiouni                                           </td> <td>6    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Utah                                             </td> <td>6    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Benares                                          </td> <td>5    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Allahabad                                        </td> <td>5    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Rangoon                                          </td> <td>5    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Englishmen                                       </td> <td>4    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Nagasaki                                         </td> <td>4    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Camerfield                                       </td> <td>4    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Illinois                                         </td> <td>4    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Nebraska                                         </td> <td>4    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Salt Lake City                                   </td> <td>4    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Missouri                                         </td> <td>4    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>France                                           </td> <td>3    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Dover                                            </td> <td>3    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Madras                                           </td> <td>3    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Kholby                                           </td> <td>3    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Macao                                            </td> <td>3    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Passepartout                                     </td> <td>3    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Colorado                                         </td> <td>3    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Ohio                                             </td> <td>3    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Mississippi                                      </td> <td>3    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Jordan                                           </td> <td>3    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Dublin                                           </td> <td>3    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>U.S.                                             </td> <td>3    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Flanagan                                         </td> <td>2    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Fallentin                                        </td> <td>2    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Baring                                           </td> <td>2    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Alabama                                          </td> <td>2    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Consul                                           </td> <td>2    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Egypt                                            </td> <td>2    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Parsees                                          </td> <td>2    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Bengal                                           </td> <td>2    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Salcette                                         </td> <td>2    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Chandernagor                                     </td> <td>2    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Parsee

# %%
import matplotlib
matplotlib.use('Agg', warn=False)
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
places_table.hist('count')

# %% [markdown]
# Let's keep the places with more than 5 mentions.

# %%
places5_table = places_table.where('count', are.above(5))
places5_table.num_rows
# Out:
# 30

# %%
places_table.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>name</th> <th>count</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Aouda                                            </td> <td>134  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>London                                           </td> <td>64   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Hong Kong                                        </td> <td>60   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Bombay                                           </td> <td>58   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Yokohama                                         </td> <td>39   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>India                                            </td> <td>35   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>San Francisco                                    </td> <td>29   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>New York                                         </td> <td>28   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Liverpool                                        </td> <td>27   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Omaha                                            </td> <td>24   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>                                                 </td> <td>22   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>England                                          </td> <td>20   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Mongolia                                         </td> <td>20   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Tankadere                                        </td> <td>18   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Fogg                                             </td> <td>17   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Shanghai                                         </td> <td>17   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>America                                          </td> <td>14   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>the United States                                </td> <td>14   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>China                                            </td> <td>13   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Singapore                                        </td> <td>12   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Japan                                            </td> <td>12   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Sioux                                            </td> <td>12   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Paris                                            </td> <td>11   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Pillaji                                          </td> <td>9    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Brindisi                                         </td> <td>8    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Aden                                             </td> <td>8    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Sacramento                                       </td> <td>7    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Chicago                                          </td> <td>7    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Kiouni                                           </td> <td>6    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Utah                                             </td> <td>6    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Benares                                          </td> <td>5    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Allahabad                                        </td> <td>5    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Rangoon                                          </td> <td>5    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Englishmen                                       </td> <td>4    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Nagasaki                                         </td> <td>4    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Camerfield                                       </td> <td>4    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Illinois                                         </td> <td>4    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Nebraska                                         </td> <td>4    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Salt Lake City                                   </td> <td>4    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Missouri                                         </td> <td>4    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>France                                           </td> <td>3    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Dover                                            </td> <td>3    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Madras                                           </td> <td>3    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Kholby                                           </td> <td>3    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Macao                                            </td> <td>3    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Passepartout                                     </td> <td>3    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Colorado                                         </td> <td>3    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Ohio                                             </td> <td>3    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Mississippi                                      </td> <td>3    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Jordan                                           </td> <td>3    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Dublin                                           </td> <td>3    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>U.S.                                             </td> <td>3    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Flanagan                                         </td> <td>2    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Fallentin                                        </td> <td>2    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Baring                                           </td> <td>2    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Alabama                                          </td> <td>2    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Consul                                           </td> <td>2    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Egypt                                            </td> <td>2    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Parsees                                          </td> <td>2    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Bengal                                           </td> <td>2    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Salcette                                         </td> <td>2    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Chandernagor                                     </td> <td>2    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Parsee

# %% [markdown]
# The list of places isn't perfect -it still contains non-places (such as?).  But let's move on to our next step as that may weed out the non-places.

# %% [markdown]
# ### Step 3. Geocoding with Geopy and Nominatim
#
# Geocoding is the process of determining the geographic coordinates for named places, zip codes, or street addresses. Geocoding will allow us to map these locations.
#
# To do this we need to compare our place names with a database of places and geometric representations of these places. We will use the **geocoders** module of the **Geopy** package to do this. Geopy.geocoders provides access to several different geocoding tools, the most popular and accurate of which is the **Google Geocoding API**.  But we will use the free and easy `Nominatim` as it has few restrictions and requires no API key.

# %%
from geopy.geocoders import Nominatim
#import time

geolocator = Nominatim(timeout=10)

# %% [markdown]
# Check out syntax for and the output of geocoding one named place.

# %%
loc1 = geolocator.geocode("Berkeley")

# %%
loc1
# Out:
# Location(Berkeley, Alameda County, California, USA, (37.8708393, -122.2728639, 0.0))

# %%
loc1 #.tab
# Out:
# Location(Berkeley, Alameda County, California, USA, (37.8708393, -122.2728639, 0.0))

# %%
loc1.raw
# Out:
# {'boundingbox': ['37.835727', '37.9066896', '-122.3686793', '-122.2341962'],
#  'class': 'place',
#  'display_name': 'Berkeley, Alameda County, California, USA',
#  'icon': 'https://nominatim.openstreetmap.org/images/mapicons/poi_place_city.p.20.png',
#  'importance': 0.695505117607742,
#  'lat': '37.8708393',
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'lon': '-122.2728639',
#  'osm_id': '2833528',
#  'osm_type': 'relation',
#  'place_id': '198436583',
#  'type': 'city'}

# %% [markdown]
# Now try a non-US place name, one that is no longer used.

# %%
loc2 = geolocator.geocode("Bombay")

# %%
loc2
# Out:
# Location(Mumbai, Mumbai City, Maharashtra, India, (18.9387711, 72.8353355, 0.0))

# %% [markdown]
# ## Challenge
#
# In the cell below write print statements to display the following for `loc2`.
#
# - place name for display
# - latitude
# - longitude
# - place type

# %%
# YOUR CODE HERE

# %% [markdown]
# Let's geocode our places5_table to get the latitude, longitude, and place type of each location.

# %%
for i in range(0, places5_table.num_rows):
    print(places5_table.column('name').item(i))
# Out:
# Aouda
# London
# Hong Kong
# Bombay
# Yokohama
# India
# San Francisco
# New York
# Liverpool
# Omaha
#
# England
# Mongolia
# Tankadere
# Fogg
# Shanghai
# America
# the United States
# China
# Singapore
# Japan
# Sioux
# Paris
# Pillaji
# Brindisi
# Aden
# Sacramento
# Chicago
# Kiouni
# Utah

# %%
# Define our output table structure
#geo_tab = Table(["latitude", "longitude", "name_in_text", "full_name","num_mentions", "place_type"])
geo_tab = Table(["name_in_text","num_mentions"])

#for name in places.keys():  # only want to loop through unique place names to call once per place name
for i in range (0, 4):
    name =  places5_table.column('name').item(i)
    count = places5_table.column('count').item(i)
    
    geo_tab.append([name, count])

geo_tab.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>name_in_text</th> <th>num_mentions</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Aouda       </td> <td>134         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>London      </td> <td>64          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Hong Kong   </td> <td>60          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Bombay      </td> <td>58          </td>
#         </tr>
#     </tbody>
# </table>

# %%
# Define our output table structure
geo_tab = Table(["latitude", "longitude", "name_in_text", "full_name","num_mentions", "place_type"])

for i in range (0, places5_table.num_rows):
    name =  places5_table.column('name').item(i)
    num_mentions = places5_table.column('count').item(i)
    
    print("Geocoding " + name + "..." + " with " + str(num_mentions) + " counts....")
    
    # finds the lat and lon for this name
    location = geolocator.geocode(name)
    
    try:
        # index the raw response for lat and lon
        lat = float(location.raw["lat"])
        lon = float(location.raw["lon"])
        full_name = location.raw['display_name']
        place_type = location.raw['type']
 
        # add to output table
        geo_tab.append([lat , lon , name, full_name, num_mentions, place_type])
    
    except:
        pass
# Out:
# Geocoding Aouda... with 134 counts....
# Geocoding London... with 64 counts....
# Geocoding Hong Kong... with 60 counts....
# Geocoding Bombay... with 58 counts....
# Geocoding Yokohama... with 39 counts....
# Geocoding India... with 35 counts....
# Geocoding San Francisco... with 29 counts....
# Geocoding New York... with 28 counts....
# Geocoding Liverpool... with 27 counts....
# Geocoding Omaha... with 24 counts....
# Geocoding ... with 22 counts....
# Geocoding England... with 20 counts....
# Geocoding Mongolia... with 20 counts....
# Geocoding Tankadere... with 18 counts....
# Geocoding Fogg... with 17 counts....
# Geocoding Shanghai... with 17 counts....
# Geocoding America... with 14 counts....
# Geocoding the United States... with 14 counts....
# Geocoding China... with 13 counts....
# Geocoding Singapore... with 12 counts....
# Geocoding Japan... with 12 counts....
# Geocoding Sioux... with 12 counts....
# Geocoding Paris... with 11 counts....
# Geocoding Pillaji... with 9 counts....
# Geocoding Brindisi... with 8 counts....
# Geocoding Aden... with 8 counts....
# Geocoding Sacramento... with 7 counts....
# Geocoding Chicago... with 7 counts....
# Geocoding Kiouni... with 6 counts....
# Geocoding Utah... with 6 counts....

# %%
geo_tab.sort('longitude', descending=False).show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>latitude</th> <th>longitude</th> <th>name_in_text</th> <th>full_name</th> <th>num_mentions</th> <th>place_type</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>37.7793 </td> <td>-122.419 </td> <td>San Francisco    </td> <td>SF, California, USA                                         </td> <td>29          </td> <td>city          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>38.5816 </td> <td>-121.494 </td> <td>Sacramento       </td> <td>Sacramento, Sacramento County, California, USA              </td> <td>7           </td> <td>city          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>39.4225 </td> <td>-111.714 </td> <td>Utah             </td> <td>Utah, USA                                                   </td> <td>6           </td> <td>administrative</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>39.7837 </td> <td>-100.446 </td> <td>the United States</td> <td>USA                                                         </td> <td>14          </td> <td>administrative</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>43.0574 </td> <td>-96.1602 </td> <td>Sioux            </td> <td>Sioux County, Iowa, USA                                     </td> <td>12          </td> <td>administrative</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>41.2587 </td> <td>-95.9379 </td> <td>Omaha            </td> <td>Omaha, Douglas County, Nebraska, USA                        </td> <td>24          </td> <td>city          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>31.1774 </td> <td>-94.7866 </td> <td>Fogg             </td> <td>Fogg, Diboll, Angelina County, Texas, 75941, USA            </td> <td>17          </td> <td>residential   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>41.8756 </td> <td>-87.6244 </td> <td>Chicago          </td> <td>Chicago, Cook County, Illinois, USA                         </td> <td>7           </td> <td>city          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>4.81805 </td> <td>-75.6889 </td> <td>America          </td> <td>America, Río Otún, Perimetro Urbano Pereira, Pereira, Ri ...</td> <td>14          </td> <td>administrative</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>40.7309 </td> <td>-73.9872 </td> <td>New York         </td> <td>NYC, New York, USA                                          </td> <td>28          </td> <td>city          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>53.4055 </td> <td>-2.98054 </td> <td>Liverpool        </td> <td>Liverpool, North West England, England, UK                  </td> <td>27          </td> <td>city          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>52.7955 </td> <td>-0.54024 </td> <td>England          </td> <td>England, UK                                                 </td> <td>20          </td> <td>administrative</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>51.5073 </td> <td>-0.127647</td> <td>London           </td> <td>London, Greater London, England, SW1A 2DU, UK               </td> <td>64          </td> <td>city          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>8.73059 </td> <td>1.05093  </td> <td>Aouda            </td> <td>Aouda, Sotouboua, Région Centrale, Togo                     </td> <td>134         </td> <td>village       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>48.8566 </td> <td>2.3515   </td> <td>Paris            </td> <td>Paris, Île-de-France, France métropolitaine, France         </td> <td>11          </td> <td>city          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>40.6395 </td> <td>17.9455  </td> <td>Brindisi         </td> <td>Brindisi, BR, PUG, Italia                                   </td> <td>8           </td> <td>city          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>12.7896 </td> <td>45.0285  </td> <td>Aden             </td> <td>عدن, اليمن                                                  </td> <td>8           </td> <td>city          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>18.9388 </td> <td>72.8353  </td> <td>Bombay           </td> <td>Mumbai, Mumbai City, Maharashtra, India                     </td> <td>58          </td> <td>city          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>22.3511 </td> <td>78.6677  </td> <td>India            </td> <td>India                                                       </td> <td>35          </td> <td>administrative</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>46.825  </td> <td>103.85   </td> <td>Mongolia         </td> <td>Монгол улс                                                  </td> <td>20          </td> <td>administrative</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1.29048 </td> <td>103.852  </td> <td>Singapore        </td> <td>Singapore, Central, 178957, Singapore                       </td> <td>12          </td> <td>city          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>35.0001 </td> <td>105      </td> <td>China            </td> <td>中国                                                          </td> <td>13          </td> <td>administrative</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>22.2793 </td> <td>114.163  </td> <td>Hong Kong        </td> <td>香港 Hong Kong, 中西區 Central and Western District, 香港島 Hong ...</td> <td>60          </td> <td>city          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>31.2253 </td> <td>121.489  </td> <td>Shanghai         </td> <td>上海市, 黄浦区, 上海市, 200010, 中国                                   </td> <td>17          </td> <td>city          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>36.5748 </td> <td>139.239  </td> <td>Japan            </td> <td>日本                                                          </td> <td>12          </td> <td>administrative</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>35.445  </td> <td>139.637  </td> <td>Yokohama         </td> <td>横浜市, 神奈川県, 関東地方, 日本                                         </td> <td>39          </td> <td>city          </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# Now that the places are geocoded we can create an interactive map of the locations using the  `folium` Python library.

# %%
# Out:
# datascience.tables.Table

# %%
my_map = folium.Map(location=(np.mean(geo_tab['latitude']), np.mean(geo_tab['longitude'])), zoom_start=2)
display(my_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
my_map = folium.Map(location=(np.mean(geo_tab['latitude']), np.mean(geo_tab['longitude'])), zoom_start=2)

for latitude, longitude,name, num_mentions in geo_tab.select(['latitude','longitude','name_in_text', 'num_mentions']).rows:
    folium.Marker(
            location=[latitude, longitude],
            popup=folium.Popup(
                            folium.IFrame(
                                html= name + " (" + str(num_mentions) + ")",
                                width=150,
                                height=40),
                                max_width=2650
                            )
            ).add_to(my_map)

display(my_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We can make fancier maps by using data values to drive the symbology. See the documentation for `folium.CircleMarker`, for example.

# %%
#folium.Circle?

# %%
my_map = folium.Map(location=(np.mean(geo_tab['latitude']), np.mean(geo_tab['longitude'])), zoom_start=2)

for latitude, longitude,name, num_mentions in geo_tab.select(['latitude','longitude','name_in_text', 'num_mentions']).rows:
    folium.CircleMarker(
        location=[latitude, longitude],
        fill=True,
        fill_color="red",
        radius = num_mentions.astype(float)/2,
        #radius = pow(10,num_mentions.astype(float)), #num_mentions.astype(float) + 1) * 100000,
        popup=folium.Popup(
            folium.IFrame(
                html= name + " (" + str(num_mentions) + ")",
                width=150,
                height=40),
                max_width=2650
                )
            ).add_to(my_map)

display(my_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Evaluate our work
#
# How well did this process work in identifying the locations visited by the characters in `Around the World in 80 Days`?
#
# >"These dates were inscribed in an itinerary divided into columns,
# indicating the month, the day of the month, and the day for the
# stipulated and actual arrivals at each principal point Paris, Brindisi,
# Suez, Bombay, Calcutta, Singapore, Hong Kong, Yokohama, San Francisco,
# New York, and London--from the 2nd of October to the 21st of December;"

# %% [markdown]
# Add the actual route map is...
# <img src="http://kickasstrips.com/wp-content/uploads/2014/06/Around_the_World_in_Eighty_Days_map_Jules_Verne.jpg" width="800"></img>
#
# See: (http://kickasstrips.com/2014/06/around-the-world-in-80-days-phileas-foggs-original-journey/)

# %% [markdown]
# ### Discussion
#
# 1. Are there places that you would like to remove from the table? If yes, why?
# 2. Name some of the reasons why place name geoparsing is difficult.
# 3. Why is place name "data cleaning" difficult.
# 4. Why might we remove the places "Fogg", "Passepartout" and 'Aouda'. Take a look at the ebook URL for clues.
# 5. Can you guess what types of documents would geoparse better than others? worse?
# 6. What are the alternatives to automated geoparsing?
# 7. Discuss some of the pros & cons of referencing that big city across the bay as 'San Francisco' vs. '37.77493, -122.41942'.

# %% [markdown]
# <hr>
# Created by `pattyf@berkeley.edu`. Last updated November 2018.
